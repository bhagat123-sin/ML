# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("Home_Data.csv")

# %%
df
# Out:
#    Area   Price
# 0  2000  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.Area,df.Price, color='green', marker='*')
plt.xlabel("Are_Value")
plt.ylabel(" Price_Value")
plt.title(" Ares VS Price")
# Out:
# Text(0.5, 1.0, ' Ares VS Price')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Area']],df.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[2000]])
# Out:
# C:\Users\intel\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([521742.95774648])

# %%
reg.coef_
# Out:
# array([89.87676056])

# %%
reg.intercept_
# Out:
# 341989.43661971827

# %%
df1 = pd.read_csv("Area.csv")

# %%
df1
df1.head(5)
# Out:
#    Area
# 0  1000
# 1  3400
# 2  4000
# 3  5400
# 4  3789

# %%
b = reg.predict(df1)
# Out:
# array([ 431866.1971831 ,  647570.42253521,  701496.47887324,
#         827323.94366197,  682532.48239437,  836311.61971831,
#         953151.4084507 , 1043028.16901408, 1150880.28169014])

# %%
df1['Prices'] = b

# %%
df1.to_csv('Prediction.csv', index=False)

# %%
plt.scatter(df.Area,df.Price, color='red' , marker='+')
plt.plot(df.Area,reg.predict(df[['Area']]),color='blue')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Predict House Price')
# Out:
# Text(0.5, 1.0, 'Predict House Price')
